# %%
import zipfile
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
with zipfile.ZipFile("Dataset/792_3538_bundle_archive.zip","r") as z:
    z.extractall("Dataset/")

# %%
df = pd.read_csv('Dataset/KaggleV2-May-2016.csv')

# %%
df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
df.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %% [markdown]
# ### Dataset has no null vaues

# %%
df.describe()
# Out:
#           PatientId  AppointmentID            Age
# count  1.105270e+05   1.105270e+05  110527.000000
# mean   1.474963e+14   5.675305e+06      37.088874
# std    2.560949e+14   7.129575e+04      23.110205
# min    3.921784e+04   5.030230e+06      -1.000000
# 25%    4.172614e+12   5.640286e+06      18.000000
# 50%    3.173184e+13   5.680573e+06      37.000000
# 75%    9.439172e+13   5.725524e+06      55.000000
# max    9.999816e+14   5.790484e+06     115.000000

# %%
df.describe(include='all')
# Out:
#            PatientId  AppointmentID  Gender          ScheduledDay  \
# count   1.105270e+05   1.105270e+05  110527                110527
# unique           NaN            NaN       2                103549
# top              NaN            NaN       F  2016-05-06T07:09:54Z
# freq             NaN            NaN   71840                    24
# mean    1.474963e+14   5.675305e+06     NaN                   NaN
# std     2.560949e+14   7.129575e+04     NaN                   NaN
# min     3.921784e+04   5.030230e+06     NaN                   NaN
# 25%     4.172614e+12   5.640286e+06     NaN                   NaN
# 50%     3.173184e+13   5.680573e+06     NaN                   NaN
# 75%     9.439172e+13   5.725524e+06     NaN                   NaN
# max     9.999816e+14   5.790484e+06     NaN                   NaN
#
#               AppointmentDay            Age   Neighbourhood    Scholarship  \
# count                 110527  110527.000000          110527  110527.000000
# ...

# %%
df.describe(include='all')['Gender']['freq']
# Out:
# 71840

# %%
df.SMS_received.value_counts()
# Out:
# 0    75045
# 1    35482
# Name: SMS_received, dtype: int64

# %% [markdown]
# #### SMS_received column should ideally be of object or categorical type but as it contains numerical values it is considered as continuous column. We should convert it to object or categorical type

# %%
df.SMS_received = df.SMS_received.astype('category')

# %%
# Rename columns
df.rename(columns={'Hipertension':'Hypertension', 'Handcap':'Handicap'}, inplace=True)

# %% [markdown]
# Similarly for Scholarship, Hypertension, Diabetes, Alcoholism, Handicap column

# %%
df.Scholarship = pd.Categorical(df.Scholarship, categories=[0, 1])
df.Hypertension = pd.Categorical(df.Hypertension, categories=[0, 1])
df.Diabetes = df.Diabetes.astype('category')
df.Alcoholism = df.Alcoholism.astype('category')
df.Handicap = df.Handicap.astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  category
#  8   Hypertension    110527 non-null  category
#  9   Diabetes        110527 non-null  category
#  10  Alcoholism      110527 non-null  category
#  11  Handicap        110527 non-null  category
#  12  SMS_received    110527 non-null  category
#  13  No-show         110527 non-null  object
# dtypes: category(6), float64(1), int64(2), object(5)
# memory usage: 7.4+ MB

# %%
df.describe(include='all')
# Out:
#            PatientId  AppointmentID  Gender          ScheduledDay  \
# count   1.105270e+05   1.105270e+05  110527                110527
# unique           NaN            NaN       2                103549
# top              NaN            NaN       F  2016-05-06T07:09:54Z
# freq             NaN            NaN   71840                    24
# mean    1.474963e+14   5.675305e+06     NaN                   NaN
# std     2.560949e+14   7.129575e+04     NaN                   NaN
# min     3.921784e+04   5.030230e+06     NaN                   NaN
# 25%     4.172614e+12   5.640286e+06     NaN                   NaN
# 50%     3.173184e+13   5.680573e+06     NaN                   NaN
# 75%     9.439172e+13   5.725524e+06     NaN                   NaN
# max     9.999816e+14   5.790484e+06     NaN                   NaN
#
#               AppointmentDay            Age   Neighbourhood  Scholarship  \
# count                 110527  110527.000000          110527     110527.0
# ...

# %%
# df.SMS_received.cat.codes will print the encoded values
df.SMS_received.cat.codes.value_counts()
# Out:
# 0    75045
# 1    35482
# dtype: int64

# %%
df.SMS_received.value_counts()
# Out:
# 0    75045
# 1    35482
# Name: SMS_received, dtype: int64

# %% [markdown]
# ### Above 2 lines tell us that 0 has been encoded as 0 and 1 as 1, so we were lucky enough that in our problem statement we wanted  0 to be encoded as 0, 1 to be encoded as 1. But what if there is a requirement where we want 0 to be encoded as 1 and 1 to be encoded as 0. In such a case we should specify the value with which we want our raw values to be encoded

# %% [markdown]
# #### This can be done when we convert it to categorical type using
#
# `df.SMS_received = pd.Categorical(df.SMS_received, categories=[1, 0])`
#
# OR
#
# `df.SMS_received = df.SMS_received.astype('category')
# df.SMS_received.cat.set_categories([1, 0], inplace=True)`

# %%
df.SMS_received.cat.set_categories([1, 0]).cat.codes.value_counts()
# Out:
# 1    75045
# 0    35482
# dtype: int64

# %% [markdown]
# ##### In the above line we have encoded 0 as 1 and 1 as 0. So we can also observe that value_counts() for 0 and 1 have reversed

# %% [markdown]
# # No to LabelEncoder

# %%
dummy = pd.DataFrame(
        {'Hours of dedication': pd.Categorical(
              values =  ['25-30', '20-25', '5-10', '5-10', '40-45', 
                         '0-5', '15-20', '20-25', '30-35', '5-10',
                         '10-15', '45-50', '20-25'],
              categories=['0-5', '5-10', '10-15', '15-20', 
                          '20-25', '25-30','30-35','40-45', '45-50']),

         'Assignments avg grade': pd.Categorical(
             values =  ['B', 'C', 'F', 'C', 'B', 
                        'D', 'C', 'A', 'B', 'B', 
                        'B', 'A', 'D'],
             categories=['F', 'D', 'C', 'B','A']),

         'Result': pd.Categorical(
             values = ['Pass', 'Pass', 'Fail', 'Fail', 'Pass', 
                       'Fail', 'Fail','Pass','Pass', 'Fail', 
                       'Fail', 'Pass', 'Pass'], 
             categories=['Fail', 'Pass'])
        }
    )

# %%
dummy.head()
# Out:
#   Hours of dedication Assignments avg grade Result
# 0               25-30                     B   Pass
# 1               20-25                     C   Pass
# 2                5-10                     F   Fail
# 3                5-10                     C   Fail
# 4               40-45                     B   Pass

# %%
X = dummy.apply(lambda x: x.cat.codes)
X.head()
# Out:
#    Hours of dedication  Assignments avg grade  Result
# 0                    5                      3       1
# 1                    4                      2       1
# 2                    1                      0       0
# 3                    1                      2       0
# 4                    7                      3       1

# %%
from sklearn import tree

dt = tree.DecisionTreeClassifier()
y = X.pop('Result')
dt.fit(X, y)
# Out:
# c:\users\bonsai\appdata\local\programs\python\python37\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# c:\users\bonsai\appdata\local\programs\python\python37\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# c:\users\bonsai\appdata\local\programs\python\python37\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# c:\users\bonsai\appdata\local\programs\python\python37\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# ...

# %%
t = tree.plot_tree(dt, 
                   feature_names = X.columns,
                   class_names=["Fail", "Pass"],
                   filled = True,
                   label='all',
                   rounded=True)

# %%
df_wrong = dummy.copy()
df_wrong['Hours of dedication'].cat.set_categories(
             ['0-5','40-45', '25-30', '10-15', '5-10', '45-50','15-20', 
              '20-25','30-35'], inplace=True)
df_wrong['Assignments avg grade'].cat.set_categories(
             ['A', 'C', 'F', 'D', 'B'], inplace=True)

# %%
# rcParams['figure.figsize'] = 14,18
plt.figure(figsize=(14, 18))
X_wrong = df_wrong.drop(['Result'],1).apply(lambda x: x.cat.codes)
y = df_wrong.Result

dt_wrong = tree.DecisionTreeClassifier()
dt_wrong.fit(X_wrong, y)

t = tree.plot_tree(dt_wrong, 
                   feature_names = X_wrong.columns,
                   class_names=["Fail", "Pass"],
                   filled = True,
                   label='all',
                   rounded=True)
